# %% [markdown]
# <a href="https://colab.research.google.com/github/aadios2311-wq/Equity-Research-Macro-Tracker/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf

# Let's get the 10-Year Treasury Yield (^TNX) and the S&P 500 (^GSPC)
data = yf.download(['^TNX', '^GSPC'], start="2023-01-01")
data['Close'].plot()
# Out:
# /tmp/ipykernel_11713/2559153254.py:4: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(['^TNX', '^GSPC'], start="2023-01-01")
# [*********************100%***********************]  2 of 2 completed
# <Axes: xlabel='Date'>

# %%
import yfinance as yf
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 1. Define the assets you want to track
# Brent Oil, US 10Y Yield, Nifty 50 (India), and Apple (US Tech), and Google
tickers = ["BZ=F", "^TNX", "^NSEI", "AAPL", "GOOGL"]

# 2. Download the data (last 2 years)
df = yf.download(tickers, period="2y")['Close']

# 3. Convert prices to daily percentage changes (Returns)
# This is crucial! Correlations on raw prices are often misleading.
returns = df.pct_change().dropna()

# 4. Create the correlation matrix
matrix = returns.corr()

# 5. Visualize it with a Heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(matrix, annot=True, cmap='RdBu', center=0)
plt.title('Asset Correlation Matrix: Macro vs. Equity')
plt.show()
# Out:
# /tmp/ipykernel_11713/3303512752.py:11: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(tickers, period="2y")['Close']
# [*********************100%***********************]  5 of 5 completed
# /tmp/ipykernel_11713/3303512752.py:15: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   returns = df.pct_change().dropna()

# %%
# Initialize the ticker
exchange_rate = yf.Ticker("INR=X")

# Get historical market data for the last month
history = exchange_rate.history(period="1wk")

print(history['Close'])
# Out:
# Date
# 2026-05-01 00:00:00+01:00    94.759102
# 2026-05-04 00:00:00+01:00    94.903000
# 2026-05-05 00:00:00+01:00    95.259399
# 2026-05-06 00:00:00+01:00    95.182999
# 2026-05-07 00:00:00+01:00    94.608002
# 2026-05-08 00:00:00+01:00    94.470001
# Name: Close, dtype: float64
